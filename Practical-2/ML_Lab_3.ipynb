# %%
# !ls
# Out:
# cars.csv  Customer.csv	sample_data

# %%
import pandas as pd
df = pd.read_csv('cars.csv')
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df1 = pd.read_csv('Customer.csv')
df1.head()
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
pd.isnull(df).sum()
# Out:
# brand            0
# km_driven        0
# fuel             0
# owner            0
# selling_price    0
# dtype: int64

# %%
df.groupby('brand').count()
# Out:
#                km_driven  fuel  owner  selling_price
# brand
# Ambassador             3     3      3              3
# Ashok                  1     1      1              1
# Audi                  31    31     31             31
# BMW                  109   109    109            109
# Chevrolet            190   190    190            190
# Daewoo                 3     3      3              3
# Datsun                58    58     58             58
# Fiat                  41    41     41             41
# Force                  5     5      5              5
# Ford                 340   340    340            340
# Honda                393   393    393            393
# Hyundai             1238  1238   1238           1238
# Isuzu                  3     3      3              3
# Jaguar                68    68     68             68
# Jeep                  26    26     26             26
# Kia                    3     3      3              3
# Land                   5     5      5              5
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['brand_encoded'] = label_encoder.fit_transform(df['brand'])
print(df)
# Out:
#          brand  km_driven    fuel         owner  selling_price  brand_encoded
# 0       Maruti     145500  Diesel   First Owner         450000             20
# 1        Skoda     120000  Diesel  Second Owner         370000             27
# 2        Honda     140000  Petrol   Third Owner         158000             10
# 3      Hyundai     127000  Diesel   First Owner         225000             11
# 4       Maruti     120000  Petrol   First Owner         130000             20
# ...        ...        ...     ...           ...            ...            ...
# 7096      Ford      33000  Diesel   First Owner         880000              9
# 7097  Mahindra      60000  Diesel   First Owner         700000             19
# 7098  Mahindra      60000  Diesel   First Owner         600000             19
# 7099    Nissan      40000  Petrol   First Owner         700000             23
# 7100      Tata      60000  Diesel   First Owner         400000             28
#
# [7101 rows x 6 columns]

# %%
df.groupby(['brand', 'brand_encoded']).size()
# Out:
# brand          brand_encoded
# Ambassador     0                   3
# Ashok          1                   1
# Audi           2                  31
# BMW            3                 109
# Chevrolet      4                 190
# Daewoo         5                   3
# Datsun         6                  58
# Fiat           7                  41
# Force          8                   5
# Ford           9                 340
# Honda          10                393
# Hyundai        11               1238
# Isuzu          12                  3
# Jaguar         13                 68
# Jeep           14                 26
# Kia            15                  3
# Land           16                  5
# Lexus          17                 32
# MG             18                  3
# Mahindra       19                700
# Maruti         20               2145
# Mercedes-Benz  21                 44
# Mitsubishi     22                 10
# Nissan         23                 72
# ...

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price  brand_encoded
# 0   Maruti     145500  Diesel   First Owner         450000             20
# 1    Skoda     120000  Diesel  Second Owner         370000             27
# 2    Honda     140000  Petrol   Third Owner         158000             10
# 3  Hyundai     127000  Diesel   First Owner         225000             11
# 4   Maruti     120000  Petrol   First Owner         130000             20

# %%
df.groupby('fuel').size()
# Out:
# fuel
# CNG         51
# Diesel    3827
# LPG         34
# Petrol    3189
# dtype: int64

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['fuel_encoded'] = label_encoder.fit_transform(df['fuel'])
print(df)
# Out:
#          brand  km_driven    fuel         owner  selling_price  brand_encoded  \
# 0       Maruti     145500  Diesel   First Owner         450000             20
# 1        Skoda     120000  Diesel  Second Owner         370000             27
# 2        Honda     140000  Petrol   Third Owner         158000             10
# 3      Hyundai     127000  Diesel   First Owner         225000             11
# 4       Maruti     120000  Petrol   First Owner         130000             20
# ...        ...        ...     ...           ...            ...            ...
# 7096      Ford      33000  Diesel   First Owner         880000              9
# 7097  Mahindra      60000  Diesel   First Owner         700000             19
# 7098  Mahindra      60000  Diesel   First Owner         600000             19
# 7099    Nissan      40000  Petrol   First Owner         700000             23
# 7100      Tata      60000  Diesel   First Owner         400000             28
#
#       fuel_encoded
# ...

# %%
df.groupby(['fuel', 'fuel_encoded']).size()
# Out:
# fuel    fuel_encoded
# CNG     0                 51
# Diesel  1               3827
# LPG     2                 34
# Petrol  3               3189
# dtype: int64

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price  brand_encoded  \
# 0   Maruti     145500  Diesel   First Owner         450000             20
# 1    Skoda     120000  Diesel  Second Owner         370000             27
# 2    Honda     140000  Petrol   Third Owner         158000             10
# 3  Hyundai     127000  Diesel   First Owner         225000             11
# 4   Maruti     120000  Petrol   First Owner         130000             20
#
#    fuel_encoded
# 0             1
# 1             1
# 2             3
# 3             1
# 4             3

# %%
label_encoder = LabelEncoder()
df['owner_encoded'] = label_encoder.fit_transform(df['owner'])

# %%
df.groupby(['owner', 'owner_encoded']).size()
# Out:
# owner                 owner_encoded
# First Owner           0                4606
# Fourth & Above Owner  1                 151
# Second Owner          2                1843
# Test Drive Car        3                   5
# Third Owner           4                 496
# dtype: int64

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price  brand_encoded  \
# 0   Maruti     145500  Diesel   First Owner         450000             20
# 1    Skoda     120000  Diesel  Second Owner         370000             27
# 2    Honda     140000  Petrol   Third Owner         158000             10
# 3  Hyundai     127000  Diesel   First Owner         225000             11
# 4   Maruti     120000  Petrol   First Owner         130000             20
#
#    fuel_encoded  owner_encoded
# 0             1              0
# 1             1              2
# 2             3              4
# 3             1              0
# 4             3              0

# %%
df.drop(['brand', 'fuel', 'owner'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    km_driven  selling_price  brand_encoded  fuel_encoded  owner_encoded
# 0     145500         450000             20             1              0
# 1     120000         370000             27             1              2
# 2     140000         158000             10             3              4
# 3     127000         225000             11             1              0
# 4     120000         130000             20             3              0

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Standardizing the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# Applying PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_data)

# Creating a PCA result dataframe
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])

# Visualizing the PCA result
plt.figure(figsize=(8, 6))
plt.scatter(pca_df['PC1'], pca_df['PC2'], color='blue', alpha=0.7)
plt.title('PCA Visualization')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid()
plt.show()

# %%
df1.head()
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df1['gender_encoded'] = label_encoder.fit_transform(df1['gender'])
df1['review_encoded'] = label_encoder.fit_transform(df1['review'])
df1['education_encoded'] = label_encoder.fit_transform(df1['education'])
df1['purchased_encoded'] = label_encoder.fit_transform(df1['purchased'])
print(df1)
# Out:
#     age  gender   review education purchased  gender_encoded  review_encoded  \
# 0    30  Female  Average    School        No               0               0
# 1    68  Female     Poor        UG        No               0               2
# 2    70  Female     Good        PG        No               0               1
# 3    72  Female     Good        PG        No               0               1
# 4    16  Female  Average        UG        No               0               0
# 5    31  Female  Average    School       Yes               0               0
# 6    18    Male     Good    School        No               1               1
# 7    60  Female     Poor    School       Yes               0               2
# 8    65  Female  Average        UG        No               0               0
# 9    74    Male     Good        UG       Yes               1               1
# 10   98  Female     Good        UG       Yes               0               1
# ...

# %%
df1.drop(['gender', 'review', 'education','purchased'], axis=1, inplace=True)

# %%
df1.head()
# Out:
#    age  gender_encoded  review_encoded  education_encoded  purchased_encoded
# 0   30               0               0                  1                  0
# 1   68               0               2                  2                  0
# 2   70               0               1                  0                  0
# 3   72               0               1                  0                  0
# 4   16               0               0                  2                  0

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Standardizing the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df1)

# Applying PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_data)

# Creating a PCA result dataframe
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])

# Visualizing the PCA result
plt.figure(figsize=(8, 6))
plt.scatter(pca_df['PC1'], pca_df['PC2'], color='blue', alpha=0.7)
plt.title('PCA Visualization')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid()
plt.show()

# %% [markdown]
# Tried manual

# %%
df.head()
# Out:
#    km_driven  selling_price  brand_encoded  fuel_encoded  owner_encoded
# 0     145500         450000             20             1              0
# 1     120000         370000             27             1              2
# 2     140000         158000             10             3              4
# 3     127000         225000             11             1              0
# 4     120000         130000             20             3              0

# %%
df['selling_price'].astype(int)
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 7096    880000
# 7097    700000
# 7098    600000
# 7099    700000
# 7100    400000
# Name: selling_price, Length: 7101, dtype: int64

# %%
def mean(x):
    return sum(x)/len(x)

def std(x):
    return (sum((i - mean(x))**2 for i in x)/len(x))**0.5

def Standardize_data(X):
    return (X - mean(X))/std(X)

df['km_driven'] = Standardize_data(df['km_driven'])
df['selling_price'] = Standardize_data(df['selling_price'])
df['brand_encoded'] = Standardize_data(df['brand_encoded'])
df['fuel_encoded'] = Standardize_data(df['fuel_encoded'])
df['owner_encoded'] = Standardize_data(df['owner_encoded'])
df.head()
# Out:
#    km_driven  selling_price  brand_encoded  fuel_encoded  owner_encoded
# 0   1.311128      -0.232546       0.267424     -0.893159      -0.669281
# 1   0.868757      -0.330519       1.221889     -0.893159       0.959425
# 2   1.215715      -0.590146      -1.096098      1.100969       2.588131
# 3   0.990192      -0.508094      -0.959746     -0.893159      -0.669281
# 4   0.868757      -0.624436       0.267424      1.100969      -0.669281

# %%
def covariance(x):
    return (x.T @ x)/(x.shape[0]-1)
cov_mat = covariance(df)
cov_mat
# Out:
#                km_driven  selling_price  brand_encoded  fuel_encoded  \
# km_driven       1.000141      -0.224638       0.099856     -0.257240
# selling_price  -0.224638       1.000141      -0.093106     -0.193072
# brand_encoded   0.099856      -0.093106       1.000141     -0.121176
# fuel_encoded   -0.257240      -0.193072      -0.121176      1.000141
# owner_encoded   0.276837      -0.225821       0.007554     -0.025711
#
#                owner_encoded
# km_driven           0.276837
# selling_price      -0.225821
# brand_encoded       0.007554
# fuel_encoded       -0.025711
# owner_encoded       1.000141

# %%
from numpy.linalg import eig
import numpy as np
eig_vals, eig_vecs = eig(cov_mat)
max_abs_idx = np.argmax(np.abs(eig_vecs), axis=0)
signs = np.sign(eig_vecs[max_abs_idx, range(eig_vecs.shape[0])])
eig_vecs = eig_vecs*signs[np.newaxis,:]
eig_vecs = eig_vecs.T

print('Eigenvalues \n', eig_vals)
print('Eigenvectors \n', eig_vecs)
# Out:
# Eigenvalues
#  [1.53164865 0.5390174  0.71613482 0.97935539 1.23454797]
# Eigenvectors
#  [[ 0.62625905 -0.45596282  0.25564298 -0.22159594  0.5342653 ]
#  [ 0.59657087  0.52865173  0.13243852  0.58511218 -0.06880639]
#  [-0.4281759   0.40896529  0.30160353  0.08608507  0.74231897]
#  [-0.18088729 -0.24314821  0.87294862  0.16603629 -0.34431295]
#  [-0.18933565 -0.53502486 -0.25318516  0.75733763  0.20059262]]

# %%
# We first make a list of (eigenvalue, eigenvector) tuples
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[i,:]) for i in range(len(eig_vals))]
# Then, we sort the tuples from the highest to the lowest based on eigenvalues magnitude
eig_pairs.sort(key=lambda x: x[0], reverse=True)
# For further usage
eig_vals_sorted = np.array([x[0] for x in eig_pairs])
eig_vecs_sorted = np.array([x[1] for x in eig_pairs])
print(eig_pairs)
# Out:
# [(1.531648648454463, array([ 0.62625905, -0.45596282,  0.25564298, -0.22159594,  0.5342653 ])), (1.2345479746310122, array([-0.18933565, -0.53502486, -0.25318516,  0.75733763,  0.20059262])), (0.979355386923972, array([-0.18088729, -0.24314821,  0.87294862,  0.16603629, -0.34431295])), (0.7161348195200353, array([-0.4281759 ,  0.40896529,  0.30160353,  0.08608507,  0.74231897])), (0.5390173958226664, array([ 0.59657087,  0.52865173,  0.13243852,  0.58511218, -0.06880639]))]

# %%
# Select top k eigenvectors
k = 2
W = eig_vecs_sorted[:k, :] # Projection matrix

print(W.shape)
# Out:
# (2, 5)

# %%
import matplotlib.pyplot as plt
n_features = W.shape[1]
eig_vals_total = sum(eig_vals)
explained_variance = [(i / eig_vals_total)*100 for i in eig_vals_sorted]
explained_variance = np.round(explained_variance, 2)
cum_explained_variance = np.cumsum(explained_variance)

print('Explained variance: {}'.format(explained_variance))
print('Cumulative explained variance: {}'.format(cum_explained_variance))

plt.plot(np.arange(1,n_features+1), cum_explained_variance, '-o')
plt.xticks(np.arange(1,n_features+1))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance');
plt.show()
# Out:
# Explained variance: [30.63 24.69 19.58 14.32 10.78]
# Cumulative explained variance: [ 30.63  55.32  74.9   89.22 100.  ]

# %%
X_proj = df.dot(W.T)

print(X_proj.shape)
X_proj
# Out:
# (7101, 2)
#              0         1
# 0     0.835850 -1.002209
# 1     1.717647 -0.780985
# 2     1.889006  1.716045
# 3     0.446784 -0.483318
# 4     0.295608  0.801447
# ...        ...       ...
# 7096 -1.009924 -0.534694
# 7097 -0.267502 -0.850661
# 7098 -0.211662 -0.785139
# 7099 -0.787248  0.587169
# 7100  0.213735 -0.964796
#
# [7101 rows x 2 columns]

# %%
plt.scatter(X_proj.iloc[:, 0], X_proj.iloc[:, 1], c=y)
plt.xlabel('PC1'); plt.xticks([])
plt.ylabel('PC2'); plt.yticks([])
plt.title('2 components, captures {} of total variation'.format(cum_explained_variance[1]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-24a8949138eb> in <cell line: 0>()
# ----> 1 plt.scatter(X_proj.iloc[:, 0], X_proj.iloc[:, 1], c=y)
#       2 plt.xlabel('PC1'); plt.xticks([])
#       3 plt.ylabel('PC2'); plt.yticks([])
#       4 plt.title('2 components, captures {} of total variation'.format(cum_explained_variance[1]))
#       5 plt.show()
#
# NameError: name 'y' is not defined
